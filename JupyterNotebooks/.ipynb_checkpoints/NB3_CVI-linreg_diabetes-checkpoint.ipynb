# %% [markdown]
# # Notebook 3: Linear Regression (Diabetes)

# %% [markdown]
# ## Learning Goal
# The goal of this notebook is to get hands-on experience and intuition about linear regression and regularization. We once again emphasize the difference between fitting and predicting. We will see that it is much more difficult to get good out-of-sample performance on a test set (predicting) than it is to get good in-sample performance on the training set (fitting).
#
# ## Overview:
#
# In Notebook 1: __Section II: Machine Learning is difficult__, we explored linear regression in the context of a prediction problem. In this notebook, we'll formally introduce the notion of regression and see how learning and prediction can be improved by introducing regularization. We will focus mainly on simple applications of linear regression: minimizing the mean-square-error (MSE) on the training data (i.e. in-sample error) and see how well we perform on the test data (i.e. out-of-sample error).
#
#
# As we discussed in Sec. II of the review, there is a fundamental difference between minimizing the in-sample error and minimizing the out-of-sample error. The underlying reason for this is that the training data may not be representative of the full data distribution. From a Bayesian point of view, as [David MacKay](http://www.inference.org.uk/mackay/) likes to repeat: <i>We can't make predictions without making assumptions.</i> Thus, it is sensible to introduce priors that reflect the fact that we are likely to be undersampled (especially in high dimensions).
#
# We'll consider ordinary least squares regression problem in which the "error function" is defined as the square from the deviation of our linear predictor to the true response. We will supplement this error function with a regularizer that prevents overfitting. From a Bayesian point of view, the regularization can be thought of as a prior on parameters, see Sec VI.
# Minimizing the combined in-sample error + regularization terms is the same as the <b> Maximum a posteriori probability (MAP)</b> estimate in Bayesian regression (the parameters at which the posterior probability distribution is peaked). Note that in a true Bayesian approach, we should not use the mode of the posterior but the average over all possible choices of parameters weighted by their posterior probability. In practice, this is  often not done (for computational and practical reasons).
#
#
#
# ## Least squares linear regression:
#
# Consider data of the form $(y_i,\mathbf{x}^{(i)})$ where the index $i=1\ldots n$ runs over the number of examples in the training data and $\mathbf{x}^{(i)}$ is a $p$-dimensional feature (row) vector. For notational convenience, it is useful to define the $n \times p$ <b>design matrix</b> $X$ whose rows, $\textbf{x}^{(1)},\cdots, \textbf{x}^{(n)}$, are the examples and columns, $\mathbf{X}_{:,1},\cdots, \mathbf{X}_{:,p}$,  are the measured "features" (i.e. feature predictors). We also denote the $n$-dimensional column vector of sample $i$ as $\mathbf{y}_i$ and the $p$-dimensional column vector of regression parameters $\mathbf{w}\in\mathbb{R}^p$.
#
# For ordinary least square regression (no regularization), we minimize the square loss cost function:
#
# $$
# \underset{\textbf{w}\in\mathbb{R}^p}{\operatorname{min}} ||\textbf{Xw}-\textbf{y}||_2^2 = \underset{\textbf{w}\in\mathbb{R}^p}{\operatorname{min}} \,(\mathbf{Xw}-\mathbf{y})^T(\mathbf{Xw}-\mathbf{y}),
# $$
#
# or equivalently, in component form,
# $$
# \underset{\textbf{w}\in\mathbb{R}^p}{\operatorname{min}}   \sum_{i=1}^n (y_i -\mathbf{w}\cdot\mathbf{x}^{(i)})^2.
# $$
#
# If rank$(\mathbf{X})=p$, namely, the feature predictors $\mathbf{X}_{:,1},\cdots \mathbf{X}_{:,p}$ are linearly independent, then there exists unique solution to this problem:
#
# $$
# \hat{\textbf{w}}= (\mathbf{X}^T\mathbf{X})^{-1}\mathbf{X}^T \textbf{y}
# $$

# %% [markdown]
# ### Exercise 1: ###
# <ul>
#
#
# <li> This choice of parameters correspond the maximum likehood estimate of which Likelihood function?
#
# <li> Derive $\hat{\textbf{w}}$ explicitly by solving the least square problem defined above.
#
#
# <li> Is $\hat{\textbf{w}}$ a biased or an unbiased estimator? In other words, does it give the correct answer as the number of data points goes to infinity ($n \rightarrow \infty$). To answer this question, you may assume i.i.d. (independent, identically distributed) samples $(y_i,\textbf{x}^{(i)})$.
#
# <li> Is $\hat{\textbf{w}}$ still well-defined when rank$(\mathbf{X})<p$? This happens when, for example, $n<p$.
#
# <li> Now imagine the samples are generated in the following manner: $y_i=\textbf{w}_\text{true}\cdot \textbf{x}^{(i)}+\epsilon_i$ where $\epsilon_i\sim\mathcal{N}(0,\sigma^2)$ are i.i.d. Gaussian errors. In statistics, the in-sample risk is defined as
# $$
# R(\hat{\textbf{w}}, \textbf{w}_\text{true})=\frac{1}{n}\mathbb{E}[(\mathbf{X}\hat{\textbf{w}}-\mathbf{X}{\textbf{w}_\text{true}})^2],
# $$
# where $\mathbb{E}[\cdots]$ is taken over all i.i.d pairs $(y_i,\textbf{x}^{(i)})$ and $\hat{\textbf{w}}$ is the least squares solution given above. Assuming that $\mathbf{X}$ and $\epsilon_i$ are independent, show that the risk is given by
#
# $$
# R(\hat{\textbf{w}}, \textbf{w}_\text{true}) = \sigma^2\frac{p}{n}
# $$
# What's the implication of this for fixed $p$ as $n \rightarrow \infty$? How about when $p,n$ scale together?
#
# </ul>

# %% [markdown]
# From Exercise 1, it is clear that the uniqueness of the solution is only guaranteed when rank$(\mathbf{X})>p$. But even so we still may not want to use least squares if $p$ is moderately close to $n$, because its "risk" could be quite poor. One way to deal with this is to  <i> regularize</i>.
#
# We will be concerned with two classes of regularizers: <b> L2-regularization</b> which is often called <b> Ridge-Regression</b> (or <b>Tikhonov regression</b>) and <b> L1-regularization</b> which goes under the name <b>LASSO</b> (and is closely related to <b>Compressed Sensing</b>).
#
#
# ## Ridge Regression
# In Ridge-Regression, the regularization penalty is taken to be the L2-norm of the parameters
# $$
# E_{ridge}= \lambda ||\textbf{w}||_2^2 = \lambda \textbf{w}^T \textbf{w}=\lambda \sum_{\gamma=1}^p w_\gamma w_\gamma.
# $$
#
# Thus, the model is fit by minimizing the sum of the in-sample error and the regularization term
# $$
# \mathbf{w}_{ridge}(\lambda)= \underset{\textbf{w}\in\mathbb{R}^p}{\operatorname{argmin}} ||\mathbf{X}\textbf{w}-\textbf{y}||_2^2 + \lambda ||\textbf{w}||_2^2.
# $$
# Notice that the parameter $\lambda$ controls how much we weigh the fit and regularization term.

# %% [markdown]
# ### Exercise 2: ###
# <ul>
# <li>What choice of prior does this correspond to if we are performing a MAP estimate?
# <li>Show that the solution to Ridge regression is given by $\mathbf{w}_{ridge}= (\mathbf{X}^T\mathbf{X}+\lambda I)^{-1}\mathbf{X}^T \textbf{y}$.
# <li>Express your answer in terms of the Singular Value Decomposition of $\mathbf{X}$.
# </ul>

# %% [markdown]
# ## LASSO ##
#
# We will also be interested in the case where the penalty is the L1-norm of the parameters (sum of absolute values of parameters). This is called LASSO.
# $$
# E_{LASSO}= \lambda ||\mathbf{w}||_1 = \lambda \sum_{\gamma=1}^p |w_\gamma| .
# $$
# In this case,
# $$
# \textbf{w}_{LASSO}(\lambda)= \underset{\textbf{w}\in\mathbb{R}^p}{\operatorname{argmin}} {1 \over 2n} ||\mathbf{Xw}-\mathbf{y}||_2^2 + \lambda ||\mathbf{w}||_1.
# $$
# Note the prefactor $1/(2n)$ in the loss function is not essential to this formulation. We have chosen this form to be consistent with the Scikit-Learn package in Python. As we discussed in the main text, LASSO tends to give sparse solution. In the following we're going to explore these ideas a little bit more.

# %% [markdown]
# ### Exercise 3: ###
# <ul>
# <li>What choice of prior does this correspond to if we are performing a MAP estimate?
# <li>In this case, can you derive an analytic expression for $\mathbf{w}_{LASSO}$? Do you have any ideas about how we might be able to efficiently numerically calculate this?
# <li> Do you think LASSO and Ridge Regression will give qualitatively different answers? (Consider the limits $\lambda=0$ and $\lambda = \infty$)
# </ul>

# %% [markdown]
# ## Numerical Experiments with Ridge Regression and LASSO##
#
# We will now perform some numerical experiments with the Diabetes Dataset trying to predict diabetes outcomes one year forward. More information about this data set can be found at <a href="https://archive.ics.uci.edu/ml/datasets/Diabetes">https://archive.ics.uci.edu/ml/datasets/Diabetes</a>. This dataset was described in the famous <a href="http://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf">Least Angle Regression</a> paper by Efron, Hastie, Johnstone, Tibshirani as follows:
# <blockquote>Ten baseline variables, age, sex, body mass index, average blood pressure, and six blood serum measurements were obtained for each of $n = 442$ diabetes patients, as well as the
# response of interest, a quantitative measure of disease progression one year after baseline.</blockquote>
#
#
# We start by plotting the weights for each value of $\lambda$ for Ridge Regression and LASSO. This is called a regularization path. We also compare the in-sample and out-of-sample performance between two regressions by examining the $R^2$ coefficient of determination (for detailed definition see <a href="https://en.wikipedia.org/wiki/Coefficient_of_determination">here</a>). In terms of linear regression, $R^2$ tells us how well the regression function fits the data. The best attainable fit corresponds to $R^2=1$.

# %%
from __future__ import print_function
print(__doc__)

# %matplotlib inline

# This code is modified from plot_cv_diabetes.py in the skit-learn documentation
# and plot_ridge_path.py


import numpy as np
import matplotlib.pyplot as plt
#import seaborn

from sklearn import datasets, linear_model

# Load Training Data set with 200 examples

number_examples=500
diabetes = datasets.load_diabetes()
X = diabetes.data[:number_examples]
y = diabetes.target[:number_examples]

# Set up Lasso and Ridge Regression models
ridge=linear_model.Ridge()
lasso = linear_model.Lasso()


# Chooose paths
alphas = np.logspace(-2, 2, 10)

# To see how well we learn, we partition the dataset into a training set with 150 
# as well as a test set with 50 examples. We record their errors respectively.

n_samples = 500
n_samples_train = 250
X_train, X_test = X[:n_samples_train], X[n_samples_train:]
y_train, y_test = y[:n_samples_train], y[n_samples_train:]
train_errors_ridge = list()
test_errors_ridge = list()

train_errors_lasso = list()
test_errors_lasso = list()



# Initialize coeffficients for ridge regression and Lasso

coefs_ridge = []
coefs_lasso=[]
for a in alphas:
    ridge.set_params(alpha=a)
    ridge.fit(X_train, y_train)
    coefs_ridge.append(ridge.coef_)
    
    # Use the coefficient of determination R^2 as the performance of prediction.
    train_errors_ridge.append(ridge.score(X_train, y_train))
    test_errors_ridge.append(ridge.score(X_test, y_test))
    
    lasso.set_params(alpha=a)
    lasso.fit(X_train, y_train)
    coefs_lasso.append(lasso.coef_)
    train_errors_lasso.append(lasso.score(X_train, y_train))
    test_errors_lasso.append(lasso.score(X_test, y_test))
    
###############################################################################
# Display results

# First see how the 10 features we learned scale as we change the regularization parameter
plt.subplot(1,2,1)
plt.semilogx(alphas, np.abs(coefs_ridge))
axes = plt.gca()
#ax.set_xscale('log')
#ax.set_xlim(ax.get_xlim()[::-1])  # reverse axis
plt.xlabel(r'$\lambda$',fontsize=18)
plt.ylabel('$|w_i|$',fontsize=18)
plt.title('Ridge')
#plt.savefig("plots3/Ridge_sparsity_scale.png")



plt.subplot(1,2,2)
plt.semilogx(alphas, np.abs(coefs_lasso))
axes = plt.gca()
#ax.set_xscale('log')
#ax.set_xlim(ax.get_xlim()[::-1])  # reverse axis
plt.xlabel(r'$\lambda$',fontsize=18)
#plt.ylabel('$|\mathbf{w}|$',fontsize=18)
plt.title('LASSO')
#plt.savefig("plots3/LASSO_sparsity_scale.png")
plt.show()



# Plot our performance on both the training and test data
plt.semilogx(alphas, train_errors_ridge, 'b',label='Train (Ridge)')
plt.semilogx(alphas, test_errors_ridge, '--b',label='Test (Ridge)')
plt.semilogx(alphas, train_errors_lasso, 'g',label='Train (LASSO)')
plt.semilogx(alphas, test_errors_lasso, '--g',label='Test (LASSO)')
#plt.vlines(alpha_optim, plt.ylim()[0], np.max(test_errors), color='k',
#           linewidth=3, label='Optimum on test')
plt.legend(loc='upper right')
plt.ylim([-0.01, 1.0])
plt.xlabel(r'$\lambda$',fontsize=18)
plt.ylabel('Performance')
#plt.savefig("plots3/Ridge_LASSO_sparsity_performance_Ntrain=300.png")
plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %% [markdown]
# ### Exercise 4: ###
# <ul>
# <li>What do the points $\lambda=0$ and $\lambda=10^5$ correspond to? Is it strange that the weights are not monotonic in $\alpha$? Why do you think this might be?
# <li>Make a similar regularization plot for LASSO?
# <li> What is the qualitative difference between the LASSO path and Ridge Path? Does this agree with your earlier predictions? Can you make some qualitative argument to rationalize this difference?
# <li>How do your answers change when you vary the number of examples and training set size?
# </ul>

# %% [markdown]
# ## A brief note about convexity##
#
# In Sec. VI of the review, we briefly discussed convexity. Here's a quick refresher: Recall that a set $C\subseteq\mathbb{R}^n$ is called <i> convex </i> if any $x,y\in C$ and $t\in [0,1]$,
# $$
# tx+(1-t)x \in C.
# $$
# In other words, every line segments joining $x,y$ lies entirely in $C$.
#
# A function $f:\mathbb{R}^n\rightarrow \mathbb{R}$ is called <i> convex </i> if its domain dom$(f)$ is a convex set and for any $x,y\in$dom$(f)$ and $t\in [0,1]$,
#
# $$
# f(tx+(1-t)y)\le tf(x)+(1-t)f(y).
# $$
# In other words, the function lies below the line segment joining $f(x)$ and $f(y)$. This function $f$ is called <b> strictly convex </b> if this inequality holds strictly for $x\neq y$ and $t\in(0,1)$.
#
# Why is convexity important?  <b> For convex functions, any local minimizer is a global minimizer</b>. Algorithmically, this means that in the minimization (optimization) procedure, as long as we're "going down the hill" and agree to stop when we can't go any further, then we've hit the global minimum. In addition to this, there's a menagerie of beautiful theory regarding convex duality and optimality, which gives us a way of understanding the solutions even before solving the problem itself. We refer interested readers to  <a href="http://web.stanford.edu/~boyd/cvxbook/">Boyd and Vandenberghe book on Convex Optimization</a>.
#
#
# Coming back to our regularization examples, a simple inspection reveals that both LASSO and Ridge regression are convex in $w$. What's more, Ridge is actually a <i> strictly convex </i> problem (assuming $\lambda>0$) due to presence of L2 penality. In fact, this is always true regardless of $X$ and so the ridge regression solution you worked out (presumably) in Exercise 2 is always well-defined.
#
# In contrast, LASSO is not always strictly convex and hence by convexity
# theory, it need not have a unique solution. The LASSO solution is unique under general conditions, for example, when $X$ has columns in <i> general position </i> (see <a href="https://arxiv.org/abs/1206.0313"> Tibshirani 2013</a>). To mitigate this, one can define a modified problem called the <a href="https://web.stanford.edu/~hastie/Papers/B67.2%20(2005)%20301-320%20Zou%20&%20Hastie.pdf">elastic net</a> such that the function we want to minimize is always strictly convex:
#
# $$
# \underset{\mathbf{w}\in\mathbb{R}^p}{\operatorname{min}} ||\mathbf{Xw}-\mathbf{y}||_2^2 + \lambda ||\mathbf{w}||_1 + \delta||\mathbf{w}||_2^2,
# $$
# where $\lambda,\delta\ge 0$ are regularization parameters. Now aside from uniqueness of the solution, the elastic net combines some of the desirable properties (e.g. prediction) of ridge regression with the sparsity properties of the LASSO. In the following exercise, you're going to explore a little bit about elastic net.

# %% [markdown]
# ### Exercise 4: ###
# <ul>
# <li> Play with the parameters $\lambda$ and $\delta$, when would you expect sparse solutions?
#
# <li> Plot the regularization path of elastic net. How does it depend on $\lambda$ and $\delta$?
#
# <li> Derive the analytic solution of this elastic net problem. Check your answer by looking at two limiting cases ($\lambda\rightarrow 0$ and $\delta\rightarrow 0$). Does this agree with what you found previously?
#
# </ul>

# %%
# Constructing Elastic Net Model

# Parameters of the model, a: lambda, b: delta

#a, b = 1., 1.

def plot_performance(x_arr, train_error_arr, test_error_arr, params, param_val):
    
    plt.semilogx(x_arr, train_error_arr, 'b', label='Training')
    plt.semilogx(x_arr, test_error_arr, 'g', label='Test')
    plt.xlabel('$\{PARAM}$'.format(PARAM=params[0]))
    plt.ylabel('Performance, $\{PARAM}={PARAM_VAL}$'.format(PARAM=params[1], PARAM_VAL=param_val))
    plt.legend(loc='upper right')
    plt.savefig('plots3/ElasticNetPerformance_{PARAM}={PARAM_VAL}.png'.format(PARAM=params[1], PARAM_VAL=param_val))
    plt.show()
    plt.close()

a_val = 1.
b_val = 0.1

a_arr = np.logspace(-2, 2, 10)
b_arr = np.logspace(-2, 2, 10)

train_errors_elasticnet = list()
test_errors_elasticnet = list()

for a in a_arr:
    alpha = a+b_val
    l1_ratio = a/(a+b_val)

    elastic_net = linear_model.ElasticNet(alpha=alpha, l1_ratio=l1_ratio)
    elastic_net.fit(X_train, y_train)
    
    train_errors_elasticnet.append(elastic_net.score(X_train,y_train))
    test_errors_elasticnet.append(elastic_net.score(X_test,y_test))

plot_performance(a_arr, train_errors_elasticnet, test_errors_elasticnet, ('lambda', 'delta'), b_val)

##############################

train_errors_elasticnet.clear()
test_errors_elasticnet.clear()

for b in b_arr:
    alpha = a_val+b
    l1_ratio = a_val/(a_val+b)

    elastic_net = linear_model.ElasticNet(alpha=alpha, l1_ratio=l1_ratio)
    elastic_net.fit(X_train, y_train)
    
    train_errors_elasticnet.append(elastic_net.score(X_train,y_train))
    test_errors_elasticnet.append(elastic_net.score(X_test,y_test))

plot_performance(b_arr, train_errors_elasticnet, test_errors_elasticnet, ('delta', 'lambda'), a_val)

# %% [markdown]
# ### End-of-notebook questions ###
# <ul>
#
# <li> Can you explain the difference between in-sample and out-of-sample performance? Is out-of-sample error usually larger than in-sample error? Does this depend on regularization? Recall in Exercise 1, we defined the in-sample risk as
#
# $$
# R_{in}(\hat{\textbf{w}}, \textbf{w}_\text{true})=\frac{1}{n}\mathbb{E}[(\mathbf{X}\hat{\textbf{w}}-\mathbf{X}{\textbf{w}_\text{true}})^2],
# $$
# where $\hat{\textbf{w}}= (\mathbf{X}^T\mathbf{X})^{-1}\mathbf{X}^T \textbf{y}$ is the least square solution and $\textbf{w}_\text{true}$ is the true parameter vector used to generate all samples. Following the same notation and assumption, now imagine if we're given a new data point $\textbf{x}_0$ independently drawn from the predictor distribution $\mathcal{P}$. We can define the out-of-sample risk as
# $$
# R_{out} =\mathbb{E}_{\textbf{x}^{(0)}\sim\mathcal{P}}\mathbb{E}_{(y_i,\textbf{x}_i)}[(\hat{\textbf{w}}\cdot \textbf{x}_0 -\textbf{w}_\text{true}\cdot \textbf{x}_0)^2],
# $$
# with the expectation value taken not only over the training samples $(y_i,\textbf{x}_i)$ but also over the predictor distribution $\mathcal{P}$ that generates the unseen sample $\textbf{x}^{(0)}$. One can actually show that $R_{out}\ge R_{in}$ under mild assumptions. This makes sense intuitively since it's usually harder to make prediction on unseen samples than to fit the samples given. You can numerically verify this by assuming a predictor distribution, say, $\mathcal{N}(0,\Sigma)$.
# </ul>

# %% [markdown]
# # Answers to Exercises
#
# ## Exercise 1:
#
# <ul>
#     <li>Performing least squares with minimizing the cost function $||\textbf{Xw}-\textbf{y}||_2^{2}$ is equivalent to maximizing the log-likelihood for a Gaussian likelihood function: <br> $p(y_i|\textbf{x}, \theta) = \frac{1}{\sqrt{2\pi\sigma^2}} e^{ -\frac{y_i-\vec{w}\cdot\vec{x_i}}{2\sigma^2} }$ with $p(\textbf{y}|\textbf{x}, \theta) = \prod_{i=1}^n p(y_i|\textbf{x}, \theta)$. <br>
#     Calculating the log-likelihood we see that, <br>
#     $l(\theta) = \ln p(\textbf{y}|\textbf{x}, \theta) = -\frac{1}{2\sigma^2}||\textbf{X}\textbf{w} - \textbf{y}||_2^2 + constant$ <br>
#     From the equation above, one can see that minimizing the cost function $||\textbf{Xw}-\textbf{y}||_2^{2}$ is equivalent to maximizing the log-likelihood for a Gaussian likelihood function with i.i.d. samples.
#     </li>
#     <li>
#     To derive $\hat{w}_{LS}$, one can calculate the gradient of the loss function with respect to $w$ to find the set of parameters $w_k$ that minimize the loss function. <br>
#     Loss function: $L(\textbf{w}) = ||\textbf{Xw}-\textbf{y}||_2^{2} = \sum_{i=1}^n \left( \sum_{j=1}^p X_{ij}w_j - y_i \right)^2 $ <br>
#     Taking the derivative with respect to parameter k, $w_k$, we obtain <br>
#     $\frac{\partial L}{\partial w_k} = 2 \sum_{i=1}^n X_{ik} \left(\sum_{j=1}^p X_{ij}w_j - y_i\right) = 2 \sum_{i=1}^n X^T_{ki} \left( \textbf{Xw} - \textbf{y} \right)_i = 2\left( X^T{Xw} - y \right)_k$ <br>
#     Therefore, we obtain $\nabla L = 2\left( X^TXw - y \right)$. Setting the gradient to zero and solving for $\hat{w}_{LS}$, we finally obtain <br>
#     $\hat{w}_{LS} = \left( X^TX\right)^{-1}X^Ty$ <br>
#     </li>
#     <li>$\hat{\omega_j}$ for $j=1,2,...,p$ is an unbiased estimator, such that $E[\hat{\omega_j}]=\omega_j$. <br>
#     Proof: <br>
#     $L = \sum_{i=1}^n ||\vec{y_i} - \textbf{X}\vec{\omega}||_2^2 = \sum_{i=1}^n \left( y_i - \sum_{j=1}^p X_{ij}\omega_j \right)^2$ <br>
#     Minimizing with respect to $\omega_k$; <br>
#     $\frac{\partial L}{\partial \omega_k} = 2\sum_{i=1}^n \left( y_i - \sum_{j=1}^p X_{ij}\omega_j \right)(-X_{ik}) = 0$ <br>
#     $\sum_{i=1}^n X_{ik}\left( y_i - \sum_{j=1}^p X_{ij}\omega_j \right) = 0$ <br>
#     $\sum_{i=1}^n X_{ik}\left( y_i - \sum_{j\neq k} X_{ij}\omega_j - X_{ik}\omega_k\right) = 0$ <br>
#     Solving for $\omega_k$, we get <br>
#     $\omega_k = \frac{\sum_{i=1}^n X_{ik}y_i - \sum_{i=1}^n \sum_{j \neq k} X_{ik}X_{ij}\omega_j }{\sum_{i=1}^n X_{ik}^2}$ <br>
#     Taking the expectation values and using $E[X/Y]=E[X]E[1/Y]$ and $E[y_i] = \sum_{j=1}^p X_{ij}\omega_j$, we get <br>
#     $E(\omega_k) = \frac{\sum_{i=1}^n X_{ik} \left( \sum_{j=1}^p X_{ij} \omega_j - \sum_{j \neq k} X_{ij} \omega_j \right)}{\sum_{i=1}^n X_{ik}^2}$ <br>
#     The numerator simplifies, <br>
#     $E(\omega_k) = \frac{\sum_{i=1}^n X_{ik}^2 \omega_k}{\sum_{i=1}^n X_{ik}^2} = \omega_k$ <br>
#     We obtained the result that $E(\omega_k) = \omega_k$. Therefore, we conclude that least squares estimator $\hat{\omega}_{LS}$ is unbiased.
#     </li>
#     <li>
#         For the case where $rank(X) < p$, one can observe that there are infinitely many number of solutions to the least squares problem, since in this case if any $w_0$ is a solution, then $w_0 + \eta$ will also be a solution where $\textbf{X}\eta = \textbf{0}$. Therefore, $\hat{w}_{LS}$ won't be unique for such a case.
#     </li>
#     <li>We have <br>
#     $\left( X\hat{\omega} - X\omega_{true} \right)^2 = \left( \hat{\omega}^T X^T - \omega_{true}^T X^T \right) \left( X\hat{\omega} - X\omega_{true} \right)$ <br>
#     $\left( X\hat{\omega} - X\omega_{true} \right)^2 = \hat{\omega}^T X^T X \hat{\omega} - \hat{\omega}^T X^T X \omega_{true} - \omega_{true}^T X^T X \hat{\omega} + \omega_{true}^T X^T X \omega_{true}$ <br>
#     Now, we have $\hat{\omega} = \left( X^T X \right)^{-1}X^T y$ and also $\hat{\omega}^T = y^T X \left( X^T X\right)^{-1}$. Using these, we can rewrite the equation as follows: <br>
#     $\left( X\hat{\omega} - X\omega_{true} \right)^2 = y^T X \left( X^T X \right)^{-1}X^T y - y^T X \omega_{true} - \omega_{true}^T X^T y + \omega_{true}^T X^T X \omega_{true}$ <br>
#     We also know that $y = X\omega_{true} + \epsilon$, where $\epsilon$ is a n-dimensional vector containing noises, $\epsilon_1, \epsilon_2, ..., \epsilon_n$. Plugging in $y$, we get <br>
#     $y^T X \left( X^T X \right)^{-1} X^T y = \omega_{true}^T X^T X \omega_{true} + \epsilon^T X \left( X^T X \right)^{-1} X^T \epsilon + \mathcal{O}(\epsilon)$ <br>
#     Similarly, $y^T X \omega_{true} = \omega_{true}^T X^T X \omega_{true} + \mathcal{O}(\epsilon)$ and $\omega_{true}^T X^T y = \omega_{true}^T X^T X \omega_{true} + \mathcal{O}(\epsilon)$. <br>
#     Now, since each parameter in $\epsilon$ has a Gaussian distribution centered at zero, we know that for all $\mathcal{O}(\epsilon)$ terms, expectation value will be zero. One can also observe that all terms cancel out in the first equation except the one containing $\epsilon_T \epsilon$. So we are left with <br>
#     $E\left(\left( X\hat{\omega} - X\omega_{true} \right)^2\right) = E\left( \epsilon_T X \left( X^T X \right)^{-1} X^T \epsilon \right) = E\left( \epsilon_T \Lambda \epsilon \right)$ where we defined $\Lambda = X \left( X^T X\right)^{-1} X^T$. Calculating the expectation value of this expression yields <br>
#     $E\left(\left( X\hat{\omega} - X\omega_{true} \right)^2\right) = \sum_{i=1}^n \sum_{j=1}^n \epsilon_i \epsilon_j \Lambda_{ij}$ <br>
#     If $\epsilon_i$ are independent, we have $<\epsilon_i \epsilon_j> = 0$ for $i \neq j$. We can write this expression as $<\epsilon_i \epsilon_j> = \sigma^2 \delta_{ij}$. Therefore, one of the sums drop and we get the following expression <br>
#     $<\epsilon^T \Lambda \epsilon> = \sigma^2 \sum_{i=1}^n \Lambda_{ii} = \sigma^2 Tr(\Lambda)$ <br>
#     Since $\Lambda$ is the projection matrix, we can use the relationship $Tr(\Lambda) = rank(X)$. Assuming n > p, we have $Tr(\Lambda) = p$. Plugging this in, we get <br>
#     $E\left(\left( X\hat{\omega} - X\omega_{true} \right)^2\right) = p\sigma^2$ <br>
#     Therefore, the in-sample error, $R_{in}$ becomes, <br>
#     $R_{in}\left( \hat{\omega}, \omega_{true} \right) = \frac{p}{n}\sigma^2$ <br>
#     From this expression we can see that as the number of data points goes to infinity, $n \rightarrow \infty$, $R_{in} \rightarrow 0$, showing that $\hat{\omega}$ approaches $\omega_{true}$. Also, this equation sets a natural scale on the number of data points we would need for a given number of features, $p$. If $n$ and $p$ scale together, the error remains the same, therefore more features we have in a model, more data points we will need.
#     </li>
# </ul>

# %% [markdown]
# ## Exercise 2:
#
# <ul>
#     <li>The Ridge Regression problem is equivalent to maximizing the log-posterior, $P(\omega|D)$ with a Gaussian prior with mean 0 and some finite variance $\tau^2$ for each variable such that $P(\omega_j) = \frac{1}{\sqrt{2\pi\tau^2}}e^{-\frac{w_j^2}{2\tau^2}}$ and $P(\omega) = \prod_{j=1}^p P(\omega_j)$. Evaluating $\log P(\omega|D)$, we obtain <br>
#     $\log P(\omega|D) = -\frac{1}{2\sigma^2}||\textbf{X}\textbf{w} - \textbf{y}||^2_2 - \frac{1}{2\tau^2}||\vec{\omega}||^2_2$ <br>
#     Therefore, maximizing this log-posterior function is equivalent to minimizing the cost function in Ridge Regression.
#     </li>
#     <li>To find the solution to Ridge Regression, one needs to minimize the cost function: <br>
#     $L = ||\textbf{X}\omega - \textbf{y}||^2_2 + \lambda||\omega||^2_2 = \sum_{i=1}^n \left( \sum_{j=1}^p X_{ij}\omega_j - y_i\right)^2 + \lambda\sum_{i=1}^p \omega_i^2$ <br>
#     Taking the derivative with respect to $w_k$, we find <br>
#     $\frac{\partial L}{\partial w_k} = 2\sum_{i=1}^n \left( X_{ik} \sum_{j=1}^p X_{ij}\omega_j - y_i\right) + 2\lambda\omega_k = 2\left( X^T(X\omega - y) + \lambda\omega \right)_k$ <br>
#     Therefore, we get <br>
#     $\nabla L = 2\left( (X^TX+\lambda I)\omega - X^Ty \right)$ <br>
#     Equating the gradient to zero for $\hat{\omega}_{Ridge}$, we get <br>
#     $\hat{\omega}_{Ridge} = \left( X^TX+\lambda I\right)^{-1}X^Ty$ <br>
#     </li>
#     <li>
#     Singular value decomposition of X: $X = UDV^T$. If we plug this in for $\hat{\omega}_{Ridge}$, we obtain <br>
#     $\hat{\omega}_{Ridge} = \left(VDU^TUDV^T+\lambda I\right)^{-1}VDU^Ty$, also using $D^T = D$ since it is a diagonal matrix. Simplifying the expression for $\hat{\omega}_{Ridge}$ using the matrix $U$ is orthogonal, we obtain <br>
#     $\hat{\omega}_{Ridge} = \left( VD^2V^T + \lambda I \right)^{-1}VDU^Ty$ <br>
#     Now, $\left( VD^2V^T \right)^{-1} = V(D^2)^{-1}V^T$ since $V$ is orthogonal. Then <br>
#     $\hat{\omega}_{Ridge} = \left( V(D^2)^{-1}V^T + \lambda I \right)VDU^Ty$ <br>
#     This simplifies to <br>
#     $\hat{\omega}_{Ridge} = V\left( D^2 + \lambda I \right)^{-1}DU^Ty$
#     </li>
# </ul>

# %% [markdown]
# ## Exercise 3
# <ul>
#     <li>The LASSO corresponds to maximizing the log-posterior, $P(\omega|D)$ with a prior for each parameter $\omega_j$: <br>
#     $P(\omega_j) \sim e^{-\frac{|\omega_j|}{2\tau^2}}$, with $\tau$ being a constant defining the width of the exponential decay.<br>
#     And the prior is, $P(\omega) = \prod_{j=1}^p P(\omega_j)$ <br>
#     Taking the log of the posterior function will introduce the $ -\lambda \sum_{j=1}^p |\omega_j|$ term. Therefore, maximizing the log-posterior will be equivalent to minimizing LASSO cost function.
#     </li>
#     <li>The LASSO cost function is not differentiable with respect to $\omega$ at $\omega = 0$. Therefore, it is not possible to find an analytical solution to $\hat{\omega}_{LASSO}$.</li>
#     <li>Due to the $\sum_{j=1}^p |\omega_j|$ dependence in the cost function, compared to the $\sum_{j=1}^p |\omega_j|^2$ dependence of the Ridge cost function, LASSO cost function has a greater penalizing impact on small $\omega$ values. As a result, the learned $\hat{\omega}_{LASSO}$ will contain more zeroes and therefore will be more sparse compared to $\hat{\omega}_{Ridge}$. <br>
#     As $\lambda \rightarrow 0$, both $\hat{\omega}_{LASSO}$ and $\hat{\omega}_{Ridge}$ will approach to the solution of the Least Squares problem: $\hat{\omega}_{LS}$ since the effect of the penalizing term will be less and less as $\lambda \rightarrow 0$. <br>
#     As $\lambda \rightarrow \infty$, both $\hat{\omega}_{LASSO}$ and $\hat{\omega}_{Ridge}$ will approach to be a set of zeros since increasing $\lambda$ increases the constraint on the magnitude of the parameter vector, $\omega$. However, approach of $\hat{\omega}_{LASSO}$ to 0 will be quicker than $\hat{\omega}_{Ridge}$ because the former contains a penalizing term with L1-norm of $\omega$, whereas the other contains an L2-norm penalizing term.
#     </li>
# </ul>

# %% [markdown]
# ## Exercise 4
# <ul>
#     <li>The lower limit $\lambda = 0$ corresponds to vanishing of the penalizing term for both Ridge and LASSO Regression. Therefore, the two solutions $\hat{\omega}_{LASSO}$ and $\hat{\omega}_{Ridge}$ will both converge to the Least Squares solution: $\hat{\omega}_{LS}$. <br>
#         Looking at the $|\omega_i|$ vs $\lambda$ plots for LASSO and Ridge Regression, one can see that especially for smaller values of $\lambda$, the weight magnitudes are not decreasing monotonically with increasing $\lambda$. This behavior is even more appearent in the LASSO Regression case. This behavior can be explained however, keeping in mind that the parameters $\omega_j$ might be inversely correlated. <br>
#         For instance, if two parameters $\omega_j$ and $\omega_k$ are inversely correlated and $\omega_k$ is supressed by the penalizing term in the cost function, $\omega_j$ will increase due to this suppression, until the penalizing term becomes too significant as we increase $\lambda$. This explanation can also shed light on why this non-monotonic decrease is more significant in case of LASSO regression. Since LASSO regression has an L1-norm penalizing term which causes $\omega_k$ to approach zero more quickly, we observe such inverse correlations more appearently in this case.
#     </li>
#     <li>A comparison graph, comparing the performances of LASSO and Ridge Regression on training and test datasets, can be found below.
#         <img src="plots3/Ridge_LASSO_sparsity_performance.png"/> <br>
#         Again, we see that the performance of LASSO decreases quicker as $\lambda$ increases, compared to Ridge Regression.
#     </li>
#     <li>Comparing the two graphs below, one can observe that as $\lambda$ increases, the magnitude of the weights approach zero at a faster rate when we apply LASSO Regression:
#         <img src="plots3/LASSO_sparsity_scale.png"/> <br>
#     This is expected because LASSO Regression uses an L1-norm penalizing term whereas Ridge Regression uses an L2-norm penalizing term. Therefore, the effect of LASSO Regression in penalizing $\omega$ values near zero is greater compared to Ridge Regression. This difference agrees with the earlier predictions made.
#     </li>
#     <li>As we increase the number of training samples, we observe that the performance of both LASSO and Ridge Regression algorithms improve in intermediate $\lambda$ values. This behavior can be seen by looking at the following performance plot, where $N_{sample}=500$ and $N_{train}=400$:
#         <img src="plots3/Ridge_LASSO_sparsity_performance_Ntrain=400.png"/> <br>
#     Comparing this plot with the previous comparison plot above, we observe that especially for Ridge Regression the performance becomes much better and the performance reduction starts in higher $\lambda$. We also observe in this case that the difference in performance for training and testing datasets become more significant. But this can be explained by the big difference in $N_{train}$ and $N_{test}$, where $N_{train}$ is significantly larger compared to $N_{test}$. <br>
#     If we try with $N_{train} = 300$ and $N_{test} = 200$ instead, we get the following performance plot: <br>
#         <img src="plots3/Ridge_LASSO_sparsity_performance_Ntrain=300.png"/> <br>
#     Here, we again observe that the performance in intermediate $\lambda$ is better compared to lower number of samples. In addition, this time the difference between performance for training and testing datasets are less significant, the gap is very small compared to case with $N_{train} = 400$ and $N_{test} = 100$.
#     </li>
# </ul>

# %% [markdown]
# ## Exercise 5
# <ul>
#     <li>The expectation would be the solutions for $\omega$ to be more sparse when the coefficients of the two penalizing terms get higher, $\lambda$ and $\delta$, since the imposed constraint on the magnitude of the parameter vector will increase with increasing values of $\lambda$ and $\delta$, resulting in more zero entries in the final $\omega$.</li>
#     <li>Plotting a similar performance curve by calculating the $R^2$ score of the model with different $\lambda$ for $\delta=0.01$, we get the following plot: <br>
#     <img src="plots3/ElasticNetPerformance_delta=0.01.png"/> <br>
#     For a larger $\delta$, such as $\delta = 0.1$, we observe that the overall performance decreases rapidly: <br>
#     <img src="plots3/ElasticNetPerformance_delta=0.1.png"/> <br>
#     The $R^2$ coefficient as a function of second coefficient $\delta$ for $\lambda=0.01$, <br>
#     <img src="plots3/ElasticNetPerformance_lambda=0.01.png"/> <br>
#     If we significantly increase $\lambda$, for instance to $\lambda = 1.0$, we observe the reduction in performance: <br>
#     <img src="plots3/ElasticNetPerformance_lambda=1.0.png"/> <br>
#     In general, the $R^2$ coefficient drops with increasing penalizing coefficients $\lambda$ and $\delta$.
#     </li>
# </ul>
